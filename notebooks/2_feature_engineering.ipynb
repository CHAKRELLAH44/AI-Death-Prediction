# %%
# 📁 notebooks/2_feature_engineering.ipynb

import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib

# Charger les données nettoyées
df = pd.read_csv('../data/cleaned_data.csv')

# Encodage Label des colonnes catégorielles
label_cols = ['sexe', 'type_sanguin', 'maladie', 'id_service', 'medecin_traitant', 'personnel', 'id_medicament']
encoder = LabelEncoder()

for col in label_cols:
    df[col] = encoder.fit_transform(df[col])
    
# Encoder la cible
df['mortalite'] = df['mortalite'].map({'oui': 1, 'non': 0})

# Sauvegarder les features finales
df.to_csv('../data/features.csv', index=False)

# Sauvegarder l’encodeur
joblib.dump(encoder, '../data/model/feature_encoder.pkl')

print("✅ Features préparées et encodées.")
df.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[1], line 8
#       5 import joblib
#       7 # Charger les données nettoyées
# ----> 8 df = pd.read_csv('../data/cleaned_data.csv')
#      10 # Encodage Label des colonnes catégorielles
#      11 label_cols = ['sexe', 'type_sanguin', 'maladie', 'id_service', 'medecin_traitant', 'personnel', 'id_medicament']
#
# ...
